# %%
import numpy

# %% [markdown]
# Python Basic Code

# %%
print("hello")
# Out:
# hello

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=int(input("enter the value"))
b=int(input("enter the value"))
c=a+b
print(c)
# Out:
# enter the value10
# enter the value20
# 30

# %%
print(a)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
#hello

# %% [markdown]
# variables

# %%
a=10
b="goeduhub"
print(a,b)
# Out:
# 10 goeduhub

# %%
x=y=z=10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %% [markdown]
# Keywords

# %%
a = 21

b = 10

c = 0

c = a + b

print ( c )

c = a - b

print ( c )

c = a * b

print ( c )

c = a / b

print ( c )

c = a % b

print ( c )

a = 2

b = 3

c = a**b

print ( c )
# Out:
# 31
# 11
# 210
# 2.1
# 1
# 8

# %%
if a==b:
  print(a)
  print("value of a")
else:
  print(b)
# Out:
# 3
