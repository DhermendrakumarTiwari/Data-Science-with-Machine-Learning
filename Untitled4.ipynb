# %%
#list
l=[1,2,3,4,'a','hello']
l=[1,2,3,4,5]

# %%
a=max(l)

# %%
a
# Out:
# 5

# %%
#user input in list 
l1=[]
n=int(input("no of elements inside the list"))
for i in range(n):
  a=input("enterthe value of a elements")
  l.append(a)
  print(l)
# Out:
# no of elements inside the list5
# enterthe value of a elements4
# [1, 2, 3, 4, 5, '4']
# enterthe value of a elements6
# [1, 2, 3, 4, 5, '4', '6']
# enterthe value of a elements2
# [1, 2, 3, 4, 5, '4', '6', '2']
# enterthe value of a elements
# [1, 2, 3, 4, 5, '4', '6', '2', '']
# enterthe value of a elements3
# [1, 2, 3, 4, 5, '4', '6', '2', '', '3']

# %%
l1=[1,2,3]
l2=[10,20,30]
l1.extend(l2)
print(l1)
l1.append(100)
print(l1)
print(id(l1))
# Out:
# [1, 2, 3, 10, 20, 30]
# [1, 2, 3, 10, 20, 30, 100]
# 139621026733832

# %%
l1.remove(3)
l1
# Out:
# [1, 2, 10, 20, 30, 100]

# %%
l1.insert(4,'hello')
l1
# Out:
# [1, 2, 10, 20, 'hello', 30, 100]

# %%
len(l1)
# Out:
# 7

# %%
l1.index(10)
# Out:
# 2

# %%
#key, Value
d={}
d1={1:10}
print(d1)
# Out:
# {1: 10}

# %%
d1[1]   #dictionryname{key}
# Out:
# 10

# %%
d1[2]='hello'
d1
# Out:
# {1: 10, 2: 'hello'}

# %%
d1[2]=100
d1
# Out:
# {1: 10, 2: 100}

# %%
d1[2]
# Out:
# 100

# %%
d1[3]=500
d1
# Out:
# {1: 10, 2: 100, 3: 500}

# %%
d1.pop(2)
d1
# Out:
# {1: 10, 3: 500}

# %%
d1.keys()
# Out:
# dict_keys([1, 3])

# %%
d1.values()
d1
# Out:
# {1: 10, 3: 500}

# %%
for i in d1:
  print(i,d1[i])
# Out:
# 1 10
# 3 500

# %%
d1[3]=[1,2,3,4,5]
d1
# Out:
# {1: 10, 3: [1, 2, 3, 4, 5]}

# %%
len(d1)
# Out:
# 2

# %%
for i in d1.values():
  print(i)
# Out:
# 10
# [1, 2, 3, 4, 5]

# %%
d1.items()
# Out:
# dict_items([(1, 10), (3, [1, 2, 3, 4, 5])])

# %%
l=[1,2,3,4,2,3,4,5,60,12,1,1]
l
# Out:
# [1, 2, 3, 4, 2, 3, 4, 5, 60, 12, 1, 1]

# %%
#Tauple immutimmutable 
t=(1,2,3)
t
# Out:
# (1, 2, 3)

# %%
t[0]
# Out:
# 1

# %%
t[1]
# Out:
# 2

# %%
t[-1]
# Out:
# 3

# %%
x,y = 3,4

print (x,y)

a,b,c = 10,11,12

print(a,b,c)

print(b)

tuple=('a','b','c','d','e','f')

print(tuple)
# Out:
# 3 4
# 10 11 12
# 11
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
tup = ('a','e','i','o','u') #Form a tuple with name tup

print("tup is", tup)

print(tup[0])

print(tup[1])

print(tup[-1])

print(tup[-2])

print(tup[1:3])

print(tup[:3])
# Out:
# tup is ('a', 'e', 'i', 'o', 'u')
# a
# e
# u
# o
# ('e', 'i')
# ('a', 'e', 'i')

# %%
#function in python
def fun():
  a=10
  b=20
  c=a+b
  print(c)

# %%
fun()
# Out:
# 30

# %%
#Defining a function 

def ADD (a,b):  

    return a+b;  

  #taking values from the user  

a = int(input("Enter a= "))  

b = int(input("Enter b= "))  

  #Calling a function

print("Sum = ",ADD(a,b))
# Out:
# Enter a= 5
# Enter b= 4
# Sum =  9

# %%
def fun1(a,b):
  c=a+b
  print(c)

# %%
fun1(50,40)
# Out:
# 90

# %%
#defining a function

def Odd_Even( x ):

    if (x % 2 == 0): 

        print ("even")

    else: 

        print ("odd")

#Calling a function

Odd_Even(8)

Odd_Even(9)
# Out:
# even
# odd

# %%
def fun1(a,b):
  c=a+b
  d=a-b
  return c,d

# %%
x,y=fun1(50,40)

# %%
x,y
# Out:
# (90, 10)

# %%
a=int(input())
x,y=fun1(a,40)
# Out:
# 100

# %%
x
# Out:
# 140

# %%
y
# Out:
# 60

# %%
def Name_Age (Name,Age):

    print(Name)

    print(Age)

    return;

#Function calling

Name_Age(Name='XYZ',Age='21')
# Out:
# XYZ
# 21

# %%
def Name_Age (Name,Age,salary=20000):

    print(Name)

    print(Age)

    print(salary)

    return;

#Function calling

Name_Age(Name='XYZ',Age='21')

def Name_Age (Name,Age,salary=20000):

    print(Name)

    print(Age)

    print(salary)

    return;

#Function calling

Name_Age(Name='XYZ',Age='21',salary=50000)
# Out:
# XYZ
# 21
# 20000
# XYZ
# 21
# 50000

# %%
#lambda arguments: expression
x=lambda a:a*n
n=int(input())
print("sum",x(20))
# Out:
# 5
# sum 100

# %%
#Sorting in ascending order 

L=[462,45,546,6485,65,7,65,54,524,874,54,5]

Sort_L=sorted(L)

print(Sort_L)

#Descending order

Sort_L_Reverse =sorted(L, reverse=True)

print(Sort_L_Reverse)
# Out:
# [5, 7, 45, 54, 54, 65, 65, 462, 524, 546, 874, 6485]
# [6485, 874, 546, 524, 462, 65, 65, 54, 54, 45, 7, 5]

# %%
lst = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
lst[4]
# Out:
# 'e'

# %%
lst[-1]
# Out:
# 'h'

# %%
lst[2:6]
# Out:
# ['c', 'd', 'e', 'f']

# %%
lst[:6]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
lst[2:]
# Out:
# ['c', 'd', 'e', 'f', 'g', 'h']

# %%
l=[["hello","world"],["REC",[1,2,30]]]

# %%
l[0]
# Out:
# ['hello', 'world']

# %%
l[1][1][2]
# Out:
# 30

# %%
l[-1][1][2]
# Out:
# 30

# %%
s1="Goeduhub"
s2="Technology"

# %%
s2[0:1]
# Out:
# 'T'

# %%
print(s2[0]+s1[1:]+" "+s1[0]+s2[1:])
# Out:
# Toeduhub Gechnology

# %%
#how to convert string to list 
s="we are studing machine learning"
l=s.split(' ')
print(l)
# Out:
# ['we', 'are', 'studing', 'machine', 'learning']

# %%
s=input("enter a string")
l=s.split(' ')
print(l)
# Out:
# enter a stringGoedhub technology provides training in ml
# ['Goedhub', 'technology', 'provides', 'training', 'in', 'ml']

# %%
#strip 
s=" machine learning is best field to study    "

# %%
s
# Out:
# ' machine learning is best field to study    '

# %%
s=s.strip()

# %%
s
# Out:
# 'machine learning is best field to study'
