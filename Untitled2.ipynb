# %%
import sys 
number = 10
if len (sys.argv) == 2:
    number = sys.argv[1]
for i in range (number):
    print("hello world!")
# Out:
#   File "<ipython-input-7-d16d8157aabd>", line 6
#     count number = range
#                ^
# SyntaxError: invalid syntax
