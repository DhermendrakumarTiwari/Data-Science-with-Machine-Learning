# %%
2+3+9
# Out:
# 14

# %%
99-73
# Out:
# 26

# %%
23.54*-1432
# Out:
# -33709.28

# %%
100//7
# Out:
# 14

# %%
100%7
# Out:
# 2

# %%
5**3
# Out:
# 125

# %%
500*(.2*1.25)
# Out:
# 125.0

# %%
cost_of_ice_bag=1.25

# %%
profit_margin=.2

# %%
number_of_bags=500

# %%
profit_margin
# Out:
# 0.2

# %%
profit_per_bag = cost_of_ice_bag * profit_margin

# %%
profit_per_bag
# Out:
# 0.25

# %%
total_profit = number_of_bags * profit_per_bag

# %%
total_profit
# Out:
# 125.0

# %%
net_profit=100

# %%
print("The grocery store makes a total of $", total_profit)
# Out:
# The grocery store makes a total of $ 125.0

# %%
#store input data in variables
cost_of_ice_bag=1.25
profit_margin=.2
number_of_bag=500
#perform the required calculates
profit_per_bag=cost_of_ice_bag*profit_margin
total_profit=number_of_bags*profit_per_bag
#display the result
print("The grocery store makes a total of $", total_profit)
# Out:
# The grocery store makes a total of $ 125.0

# %%
my_favorite_number=1
my_least_favorite_number=5
a_neutral_number=3

# %%
#Equlity check - True
my_favorite_number==1
# Out:
# True

# %%
#Equlity check - False
my_least_favorite_number==my_least_favorite_number
# Out:
# True

# %%
cost_of_ice_bag=1.25
is_ice_bag_expensive=cost_of_ice_bag>=10
print("Is the ice bag expensive?",is_ice_bag_expensive)
# Out:
# Is the ice bag expensive? False

# %%
# !pip install jovian --upgrade --quiet
# Out:
#      |████████████████████████████████| 71kB 3.8MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
import jovian
