# %%
l=[1,2,3,2,2,4,'data']
l.count(2)
# Out:
# 3

# %% [markdown]
# #Tuple

# %%
x,y = 3,4

print (x,y)

a,b,c = 10,11,12

print(a,b,c)

print(b)

tuple=('a','b','c','d','e','f')

print(tuple)
# Out:
# 3 4
# 10 11 12
# 11
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
print('a' in tuple)
# Out:
# True

# %%
tuple[0]
# Out:
# 'a'

# %%
tuple[1]
# Out:
# 'b'

# %%
len(tuple)
# Out:
# 6

# %%
t=(1,2,'hello')
print(t)
# Out:
# (1, 2, 'hello')

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# #Dictionary

# %%
#d=dict({'red':1,'blue':2,'green':3})
d=dict({'red':1,'blue':2,'green':3})
print(d)
# Out:
# {'red': 1, 'blue': 2, 'green': 3}

# %%
type(d)
# Out:
# dict

# %%
# creating a dictionary from two list
l1=['red','green','blue']
l2=[1,2,3]
d=dict(zip(l1,l2))
d
# Out:
# {'blue': 3, 'green': 2, 'red': 1}

# %%
d.keys()
# Out:
# dict_keys(['red', 'green', 'blue'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('red', 1), ('green', 2), ('blue', 3)])

# %%
for i in d:
  print(i)
  print(d[i])
# Out:
# red
# 1
# green
# 2
# blue
# 3

# %%
for i in d.values():
  print(i)
# Out:
# 1
# 2
# 3

# %%
d.get('100')

# %%
d['blue']
# Out:
# 3

# %%
d['blue']=300
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 300}

# %%
d['orange']=100

# %%
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 300, 'orange': 100}

# %%
p={10:'hello',20:'goeduhub'}
print(d)
print(p)
# Out:
# {'red': 1, 'green': 2, 'blue': 300, 'orange': 100}
# {10: 'hello', 20: 'goeduhub'}

# %%
d.update(p)
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 300, 'orange': 100, 10: 'hello', 20: 'goeduhub'}

# %%
len(d)
# Out:
# 6

# %%
d.pop('red')
# Out:
# 1

# %%
d
# Out:
# {10: 'hello', 20: 'goeduhub', 'blue': 300, 'green': 2, 'orange': 100}

# %%
k=d.keys()
k
# Out:
# dict_keys(['green', 'blue', 'orange', 10, 20])

# %% [markdown]
# #Set

# %%
s=[1,2,3,4,5]
print(s)
print(type(s))

s=set(['a','b','c','d'])
print(s)
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# {'d', 'a', 'b', 'c'}

# %%
s={1,2,2,3,2,4,5,30,5,6,6,6}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 30}

# %%
s.add('a')
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 'a', 30}

# %%
s.update(['hello','goeduhub'])
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 'hello', 'goeduhub', 'a', 30}

# %%
s.remove(1)
s
# Out:
# {2, 3, 30, 4, 5, 6, 'a', 'goeduhub', 'hello'}

# %%
for i in s:
  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# hello
# goeduhub
# a
# 30

# %%
Set = frozenset([1,2,3,4,5])   

print(type(Set))  

for i in Set:  

    print(i);  

Set.discard(3) #Gives a error since we cannot change an element in frozenset
# Out:
# <class 'frozenset'>
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-7b603347fc98> in <module>()
#       7     print(i);
#       8
# ----> 9 Set.discard(3) #Gives a error since we cannot change an element in frozenset
#
# AttributeError: 'frozenset' object has no attribute 'discard'
