# %%
l1=[1,2,3]
l2=['apple','orange','banana','mango','grapes']


l=[]
#list()
t=(1,2,3)
l1=list(t)
print(t)
# Out:
# (1, 2, 3)

# %%
l=[]
n=int(input("enter no of elements"))
for i in range(n):
  item=input("enter element value")
  l.append(item)
  print(l)
# Out:
# enter no of elements5
# enter element value10
# ['10']
# enter element value20
# ['10', '20']
# enter element value30
# ['10', '20', '30']
# enter element value40
# ['10', '20', '30', '40']
# enter element value50
# ['10', '20', '30', '40', '50']

# %% [markdown]
# #Accessing Elements of list

# %%
l[0]
# Out:
# '10'

# %%
l[-1]
# Out:
# '50'

# %%
l[2:4]
# Out:
# ['30', '40']

# %%
l
# Out:
# ['10', '20', '30', '40', '50']

# %%
l[2]='goeduhub'
print(l)
# Out:
# ['10', '20', 'goeduhub', '40', '50']

# %%
l.insert(2,'ML')
print(l)
# Out:
# ['10', '20', 'ML', 'goeduhub', '40', '50']

# %%
l=[10,20,['a','b','c'],50]
print(l)
# Out:
# [10, 20, ['a', 'b', 'c'], 50]

# %%
l
# Out:
# [10, 20, ['a', 'b', 'c'], 50]

# %%
print(l[2][0])
# Out:
# a

# %%
l
# Out:
# [10, 20, ['a', 'b', 'c'], 50]

# %%
l=[10,20,30,40,50]

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.remove(30)

# %%
print(l)
# Out:
# [10, 20, 40, 50]

# %%
l.pop(1)
# Out:
# 20

# %%
l
# Out:
# [10, 40, 50]

# %%
del l[0]

# %%
l
# Out:
# [40, 50]

# %%
del l

# %%
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e6f469464218> in <module>()
# ----> 1 print(l)
#
# NameError: name 'l' is not defined

# %%
l=[10,20,30,40,50]
l.clear()
print(l)
# Out:
# []
