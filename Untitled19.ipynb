# %%
import tkinter

# %%
window tkinter.Tk()
label = tkinter.Label(window,text="hello").pack()
window.mainloop()
# Out:
#   File "<ipython-input-2-59f1911bbe31>", line 1
#     window tkinter.Tk()
#                  ^
# SyntaxError: invalid syntax
