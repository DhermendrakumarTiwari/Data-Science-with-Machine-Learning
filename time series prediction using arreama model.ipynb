# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("portland.csv")

# %%
df.head()
# Out:
#      Month Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114
# 0  1960-01                                                648
# 1  1960-02                                                646
# 2  1960-03                                                639
# 3  1960-04                                                654
# 4  1960-05                                                630

# %%
#ARIMA= auto regression integreted moving average

# %%
df.shape
# Out:
# (115, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                  Month Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114
# 0                                              1960-01                                                648
# 1                                              1960-02                                                646
# 2                                              1960-03                                                639
# 3                                              1960-04                                                654
# 4                                              1960-05                                                630
# ..                                                 ...                                                ...
# 110                                            1969-03                                               1419
# ...

# %%
df.dtypes
# Out:
# Month                                                                                         object
# Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Month                                                                                         0
# Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 2 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Month                                                                                       115 non-null    object
#  1   Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114  115 non-null    object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
df['Month']=pd.to_datetime(df['Month'],errors='coerce', format='%Y-%m')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 2 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Month                                                                                       114 non-null    datetime64[ns]
#  1   Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114  115 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.9+ KB

# %%
df
# Out:
#          Month Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114
# 0   1960-01-01                                                648
# 1   1960-02-01                                                646
# 2   1960-03-01                                                639
# 3   1960-04-01                                                654
# 4   1960-05-01                                                630
# ..         ...                                                ...
# 110 1969-03-01                                               1419
# 111 1969-04-01                                               1432
# 112 1969-05-01                                               1394
# 113 1969-06-01                                               1327
# 114        NaT                                              n=114
#
# [115 rows x 2 columns]

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#            Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114
# Month
# 1960-01-01                                                648
# 1960-02-01                                                646
# 1960-03-01                                                639
# 1960-04-01                                                654
# 1960-05-01                                                630

# %%
df.dtypes
# Out:
# Portland Oregon average monthly bus ridership (/100) January 1973 through June 1982, n=114    object
# dtype: object

# %%
df['avg monthly busride']=df['avg monthly busride'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avg monthly busride'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fe6589dd9fbb> in <module>()
# ...
