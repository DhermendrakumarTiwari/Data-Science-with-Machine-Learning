# %% [markdown]
# #Dhermendra Kumar Tiwari
#
# # Task-7
# #GO_STP_3831

# %% [markdown]
# #Prediction using Supervised Machine Learning using Simple Linear Regression
#
# In this task we have to find the students scores based on their study hours. This is a simple Regression problem type because it has only two variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("StudentHoursScores.csv")

# %%
print(dataset)
# Out:
#     Hours  Scores
# 0     7.7      79
# 1     5.9      60
# 2     4.5      45
# 3     3.3      33
# 4     1.1      12
# 5     8.9      87
# 6     2.5      21
# 7     1.9      19
# 8     2.7      29
# 9     8.3      81
# 10    5.5      58
# 11    9.2      88
# 12    1.5      14
# 13    3.5      34
# 14    8.5      85
# 15    3.2      32
# 16    6.5      66
# 17    2.5      21
# 18    9.6      96
# 19    4.3      42
# 20    4.1      40
# 21    3.0      30
# 22    2.6      25

# %%
dataset.head(10)
# Out:
#    Hours  Scores
# 0    7.7      79
# 1    5.9      60
# 2    4.5      45
# 3    3.3      33
# 4    1.1      12
# 5    8.9      87
# 6    2.5      21
# 7    1.9      19
# 8    2.7      29
# 9    8.3      81

# %%
dataset.tail(10)
# Out:
#     Hours  Scores
# 13    3.5      34
# 14    8.5      85
# 15    3.2      32
# 16    6.5      66
# 17    2.5      21
# 18    9.6      96
# 19    4.3      42
# 20    4.1      40
# 21    3.0      30
# 22    2.6      25

# %%
dataset.describe()
# Out:
#            Hours     Scores
# count  23.000000  23.000000
# mean    4.817391  47.695652
# std     2.709688  27.103228
# min     1.100000  12.000000
# 25%     2.650000  27.000000
# 50%     4.100000  40.000000
# 75%     7.100000  72.500000
# max     9.600000  96.000000

# %%
dataset.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     7.7      79
# 1     5.9      60
# 2     4.5      45
# 3     3.3      33
# 4     1.1      12
# 5     8.9      87
# 6     2.5      21
# 7     1.9      19
# 8     2.7      29
# 9     8.3      81
# 10    5.5      58
# 11    9.2      88
# 12    1.5      14
# 13    3.5      34
# 14    8.5      85
# 15    3.2      32
# 16    6.5      66
# 17    2.5      21
# 18    9.6      96
# 19    4.3      42
# 20    4.1      40
# 21    3.0      30
# 22    2.6      25>

# %%
dataset.nunique()
# Out:
# Hours     22
# Scores    22
# dtype: int64

# %%
dataset.max()
# Out:
# Hours      9.6
# Scores    96.0
# dtype: float64

# %%
dataset.min()
# Out:
# Hours      1.1
# Scores    12.0
# dtype: float64

# %%
dataset.shape
# Out:
# (23, 2)

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
plt.ylabel=("study Hours")
plt.xlabel=("Scores")
plt.figure(figsize=(18,9))
plt.scatter(x,y,color='g',marker='P')
plt.show()

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
import sklearn
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=1/3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() # y=ax+b
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict=model.predict(xtest)
print(y_predict)
# Out:
# [40.63327807 75.89581777 29.85861316 24.9610382  83.7319377  64.14163787
#  32.79715814 15.16588829]

# %%
ytest
# Out:
# array([40, 79, 30, 21, 85, 66, 33, 14])

# %%
y_predict
# Out:
# array([40.63327807, 75.89581777, 29.85861316, 24.9610382 , 83.7319377 ,
#        64.14163787, 32.79715814, 15.16588829])

# %%
y
# Out:
# array([79, 60, 45, 33, 12, 87, 21, 19, 29, 81, 58, 88, 14, 34, 85, 32, 66,
#        21, 96, 42, 40, 30, 25])

# %%
y_predict-ytest
# Out:
# array([ 0.63327807, -3.10418223, -0.14138684,  3.9610382 , -1.2680623 ,
#        -1.85836213, -0.20284186,  1.16588829])

# %%
model.coef_
# Out:
# array([9.79514992])

# %%
model.intercept_
# Out:
# 0.47316341303940845

# %%
m=model.predict([[8]])

# %%
m
# Out:
# array([78.83436274])

# %%
# y=ax+b
p=9.79514992*5 + 0.47316341303940135

# %%
p
# Out:
# 49.4489130130394

# %%
m==p
# Out:
# array([False])

# %%
plt.scatter(xtrain,ytrain,color="red", linewidth=5 )
plt.plot(xtrain,model.predict(xtrain), color="black",linewidth=3)
plt.title("linear Regression Model")
plt.legend(['Training','prediction'])
plt.figure(figsize=(9,9))
plt.show()

# %%
plt.scatter(xtest,ytest,color="green",linewidth=3)
plt.plot(xtest,model.predict(xtest), color="gray",linewidth=3)
plt.title("linear Regression Model")
plt.legend(['Training','prediction'])
plt.figure(figsize=(9,9))
plt.show()
